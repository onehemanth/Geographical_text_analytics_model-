# %% [markdown]
# # Spacy NER Model

# %%
import spacy
import json
from spacy.scorer import Scorer
from spacy.training.example import Example
from pathlib import Path
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load data
with open('/content/Relabeled_Training_Data.json') as fp:
  training_data = json.load(fp)

# %%
# Data
print("Classes: ", training_data['classes'])
print("Train Data Samples: ", len(training_data['annotations']))
print("Train Data (2 samples): ", training_data['annotations'][:-2])
# Out:
# Classes:  ['NAME', 'TIME', 'DATE', 'AREA', 'CITY', 'DISTRICT', 'STATE', 'COUNTRY', 'ORGANISATION', 'INCIDENT']
# Train Data Samples:  460
# Train Data (2 samples):  [['Wednesday morning 01-08-07 at 11 am local time, Mujahideen of Islamic Emirate of Afghanistan attacked American Christian kafirs terrorists occupation military base in Trara area Managi district of Kunar province. In the attack a firefight started which lasted for one hour, in which Mujahideen killed four American Christian kafirs terrorists occupation military terrorists and wounded a number of them, after the attack Mujahideen return to their positions without any difficulties. Later out of frustration the American Christian kafirs terrorists occupation military planes bombarded the area martyring and wounding civilians, destroyed houses and fields. Reported by Zabihuallah Mujahid\r', {'entities': [[0, 17, 'TIME'], [18, 26, 'DATE'], [30, 35, 'TIME'], [48, 58, 'NAME'], [167, 177, 'AREA'], [178, 193, 'DISTRICT'], [197, 212, 'STATE'], [283, 293, 'NAME'], [421, 431, 'NAME'], [671, 690, 'NAME'], [62, 92, 'ORGANISATION'], [102, 127, 'ORGANISATION'], [306, 331, 'ORGANISATION'], [513, 538, 'ORGANISATION'], [576, 628, 'INCIDENT']]}], ['Wednesday morning 01-08-07 at 11 am local time, Mujahideen of Islamic Emirate of Afghanistan attacked a transporting supplies convoy of Christian kafirs terrorists occupation militaries on Ashghi area of Zhari district of Kandahar province. In the ambush a firefight started in which Mujahideen destroyed four oil tankers, three vehicles and killed twelve Afghan National Army munafiq terrorists, after the ambush Mujahideen went back to their positions with out any difficulties. Reported by Qari Muhammad Yousaf\r', {'entities': [[0, 17, 'TIME'], [18, 26, 'DATE'], [48, 58, 'NAME'], [189, 200, 'AREA'], [204, 218, 'DISTRICT'], [222, 240, 'STATE'], [284, 294, 'NAME'], [414, 424, 'NAME'], [493, 513, 'NAME'], [30, 35, 'TIME'], [62, 92, 'ORGANISATION'], [136, 152, 'ORGANISATION'], [356, 384, 'ORGANISATION'], [93, 132, 'INCIDENT'], [295, 355, 'INCIDENT']]}], ['Wednesday morning 01-08-07 at 8 am local time, Mujahideen of Islamic Emirate of Afghanistan blew up a tank of American Christian kafirs terrorists occupation military with a remote controlled landmine in Tanki area of Medan city capital of Medanwardak province. The landmine destroyed he tank and killed four American Christian kafirs terrorists occupation military terrorists.\r', {'entities': [[0, 17, 'TIME'], [18, 26, 'DATE'], [47, 57, 'NAME'], [204, 214, 'AREA'], [218, 228, 'CITY'], [240, 261, 'STATE'], [29, 34, 'TIME'], [61, 91, 'ORGANISATION'], [110, 135, 'ORGANISATION'], [309, 334, 'ORGANISATION'], [92, 106, 'INCIDENT'], [266, 308, 'INCIDENT']]}], ['Wednesday morning 01-08-07, Mujahideen of Islamic Emirate of Afghanistan blew up a vehicle of Christian kafirs terrorists occupation militaries with a remote controlled landmine in Tarki area of Chak district of Medanwardak province. The landmine destroyed the vehicle but the number of enemies of Islam terrorists casualties could not be confirm. Reported by Zabihuallah Mujahid\r', {'entities': [[0, 17, 'TIME'], [18, 26, 'DATE'], [28, 38, 'NAME'], [181, 191, 'AREA'], [195, 208, 'DISTRICT'], [212, 233, 'STATE'], [360, 379, 'NAME'], [42, 72, 'ORGANISATION'], [94, 110, 'ORGANISATION'], [73, 90, 'INCIDENT'], [234, 268, 'INCIDENT']]}], ['Tuesday evening 31-07-07, Mujahideen of Islamic Emirate of Afghanistan fired Mortar shells on Afghan munafiqs police headquarter in Fezabad capitalize city of Badkhshan province. Later fire and smokes could be seen coming from the headquarter, the damages and causalities to the enemies of Islam terrorists in there entireties could not be confirm. Reported by Zabihuallah Mujahid\r', {'entities': [[0, 15, 'TIME'], [16, 24, 'DATE'], [26, 36, 'NAME'], [132, 139, 'CITY'], [159, 178, 'STATE'], [361, 380, 'NAME'], [40, 70, 'ORGANISATION'], [94, 109, 'ORGANISATION'], [71, 90, 'INCIDENT']]}], ['Friday afternoon 10-08-07, Mujahideen of Islamic Emirate of Afghanistan ambushed a vehicle of puppet Afghan munafiqs police terrorists in Merabad area of Taren Kot capital ...

# %%
# Shuffle the data
import random
random.shuffle(training_data['annotations'])

# Train - Test Split (90 - 10)
m = len(training_data['annotations'])
train_data = training_data['annotations'][:int(m * 0.9)]
test_data = training_data['annotations'][int(m * 0.9): ]

print("Length of Train data", len(train_data))
print("Length of Test data", len(test_data))
# Out:
# Length of Train data 414
# Length of Test data 46

# %%
# !python -m spacy download en_core_web_md
# Out:
# 2023-07-04 06:44:34.507612: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-md==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.5.0/en_core_web_md-3.5.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-md==3.5.0) (3.5.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.10.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.1.3)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
# Create a model
#nlp = spacy.blank('en')
#nlp.vocab.vectors.name = 'demo'
#nlp.add_pipe('ner')

# Pre-trained model
#nlp = spacy.load("en_core_web_md")

# From drive
# !unzip '/content/drive/MyDrive/Trained_Model.zip' -d '/content/Trained_Model'
# Out:
# Archive:  /content/drive/MyDrive/Trained_Model.zip
#    creating: /content/Trained_Model/content/Trained Model/
#    creating: /content/Trained_Model/content/Trained Model/attribute_ruler/
#   inflating: /content/Trained_Model/content/Trained Model/attribute_ruler/patterns
#    creating: /content/Trained_Model/content/Trained Model/lemmatizer/
#    creating: /content/Trained_Model/content/Trained Model/lemmatizer/lookups/
#   inflating: /content/Trained_Model/content/Trained Model/lemmatizer/lookups/lookups.bin
#    creating: /content/Trained_Model/content/Trained Model/tagger/
#   inflating: /content/Trained_Model/content/Trained Model/tagger/model
#   inflating: /content/Trained_Model/content/Trained Model/tagger/cfg
#   inflating: /content/Trained_Model/content/Trained Model/config.cfg
#    creating: /content/Trained_Model/content/Trained Model/senter/
#   inflating: /content/Trained_Model/content/Trained Model/senter/model
#  extracting: /content/Trained_Model/content/Trained Model/senter/cfg
#    creating: /content/Trained_Model/content/Trained Model/tok2vec/
#   inflating: /content/Trained_Model/content/Trained Model/tok2vec/model
#  extracting: /content/Trained_Model/content/Trained Model/tok2vec/cfg
#    creating: /content/Trained_Model/content/Trained Model/vocab/
#   inflating: /content/Trained_Model/content/Trained Model/vocab/vectors
#   inflating: /content/Trained_Model/content/Trained Model/vocab/lookups.bin
#  extracting: /content/Trained_Model/content/Trained Model/vocab/vectors.cfg
#   inflating: /content/Trained_Model/content/Trained Model/vocab/key2row
#   inflating: /content/Trained_Model/content/Trained Model/vocab/strings.json
#   inflating: /content/Trained_Model/content/Trained Model/tokenizer
#    creating: /content/Trained_Model/content/Trained Model/ner/
#   inflating: /content/Trained_Model/content/Trained Model/ner/moves
#   inflating: /content/Trained_Model/content/Trained Model/ner/model
#   inflating: /content/Trained_Model/content/Trained Model/ner/cfg
#   inflating: /content/Trained_Model/content/Trained Model/meta.json
#    creating: /content/Trained_Model/content/Trained Model/parser/
#   inflating: /content/Trained_Model/content/Trained Model/parser/moves
#   inflating: /content/Trained_Model/content/Trained Model/parser/model
#   inflating: /content/Trained_Model/content/Trained Model/parser/cfg

# %%
nlp = spacy.load('/content/Trained_Model/content/Trained Model')
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:887: UserWarning: [W095] Model 'en_core_web_md' (3.4.1) was trained with spaCy v3.4 and may not be 100% compatible with the current version (3.5.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# Add entity tags
labels = {"NAME":[], "DATE":[], "TIME":[], "AREA":[], "CITY": [],
           "DISTRICT":[], "STATE":[], "COUNTRY":[], "ORGANISATION":[], "INCIDENT":[]}
for label in labels.keys():
  nlp.get_pipe('ner').add_label(label)

# %%
# Pre-trained Optimizer
optimizer = nlp.create_optimizer()

# Blank Model
# optimizer = nlp.begin_training()

# %%
# Train
EPOCHS = 30
for i in range(EPOCHS):
  losses = {}
  random.shuffle(train_data)

  # Training batches
  for batch in spacy.util.minibatch(train_data, size=8):
    for text, annotations in batch:
      # create Example
      doc = nlp.make_doc(text)
      example = Example.from_dict(doc, annotations)
      # Update the model
      nlp.update([example], sgd=optimizer, losses=losses, drop=0.5)

  if i % 10 == 0:
    print("Epoch {0} -> {1}".format(i, losses['ner']))
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Wednesday afternoon 08-08-07, Mujahideen of Islami..." with entities "[[0, 19, 'TIME'], [20, 28, 'DATE'], [30, 40, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Kolkata: On Saturday, within hours of the National..." with entities "[[0, 7, 'CITY'], [42, 71, 'ORGANISATION'], [117, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thursday 16-08-07 at 3 pm local time, Mujahideen o..." with entities "[[9, 17, 'DATE'], [21, 36, 'TIME'], [38, 48, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Saturday early morning 11-08-07 at 6 am local time..." with entities "[[0, 22, 'TIME'], [23, 31, 'DATE'], [35, 50, 'TIME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Nine suspected terror operatives were arrested by ..." with entities "[[0, 46, 'INCIDENT'], [54, 83, 'ORGANISATION'], [1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tuesday 28-08-07 at 2:30 pm local time, a Mujahid ..." with entities "[[8, 16, 'DATE'], [20, 27, 'TIME'], [42, 49, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thursday night 16-08-07, Mujahideen of Islamic Emi..." with entities "[[0, 14, 'TIME'], [15, 23, 'DATE'], [88, 113, 'NAM...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Three members of a family were killed and two othe..." with entities "[[176, 185, 'AREA'], [191, 201, 'CITY'], [278, 283...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Wednesday morning 01-08-07 at 11 am local time, Mu..." with entities "[[0, 17, 'TIME'], [18, 26, 'DATE'], [30, 35, 'TIME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Saturday 25-08-07, a calash happened between Mujah..." with entities "[[9, 17, 'DATE'], [45, 55, 'NAME'], [140, 150, 'NA...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Friday 10-08-07 at 11 00 am local time, Mujahideen..." with entities "[[7, 15, 'DATE'], [19, 38, 'TIME'], [40, 50, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thursday morning 09-08-07 at 9 am local time, Muja..." with entities "[[0, 16, 'TIME'], [122, 124, 'COUNTRY'], [287, 301...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Seven children and four others were killed and 13,..." with entities "[[0, 131, 'INCIDENT'], [135, 146, 'STATE'], [149, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Wednesday morning 08-08-07 at 8: 00 am local time,..." with entities "[[0, 17, 'TIME'], [18, 26, 'DATE'], [30, 49, 'TIME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Wednesday morning 08-08-07, Mujahideen of Islamic ..." with entities "[[0, 17, 'TIME'], [18, 26, 'DATE'], [28, 38, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sunday night 05-08-07, Mujahideen of Islamic Emira..." with entities "[[0, 12, 'TIME'], [13, 21, 'DATE'], [23, 33, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Wednesday night 08-08-07, Mujahideen of Islamic Em..." with entities "[[0, 15, 'TIME'], [16, 24, 'DATE'], [26, 36, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sunday night 19-08-07,Mujahideen of Islamic Emirat..." with entities "[[0, 12, 'TIME'], [13, 21, 'DATE'], [144, 159, 'AR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Monday afternoon 27-08-07, Mujahideen of Islamic E..." with entities "[[0, 16, 'TIME'], [17, 25, 'DATE'], [27, 37, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Saturday early morning 11-08-07Â  at 8:00 local ti..." with entities "[[0, 22, 'TIME'], [23, 31, 'DATE'], [99, 117, 'INC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pakistan dropped weapons and some cash in Indian c..." with entities "[[0, 9, 'CITY'], [60, 94, 'INCIDENT'], [95, 108, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sunday morning 12-08-07, Mujahideen of Islamic Emi..." with entities "[[0, 14, 'TIME'], [15, 23, 'DATE'], [25, 35, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tuesday morning 14-8-07, Mujahideen of Islamic Emi..." with entities "[[0, 15, 'TIME'], [16, 23, 'DATE'], [25, 35, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Rwandan genocide was a mass slaughter of Tutsi..." with entities "[[4, 68, 'INCIDENT'], [72, 78, 'COUNTRY'], [105, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Wednesday morning 22-08-07 at 10 am local time, Mu..." with entities "[[0, 17, 'TIME'], [18, 26, 'DATE'], [30, 35, 'TIME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "police arrested a Faridabad-based employee of a mu..." with entities "[[87, 93, 'ORGANISATION'], [154, 159, 'CITY'], [18...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Saturday afternoon 04-08-07, Mujahideen of Islamic..." with entities "[[0, 18, 'TIME'], [19, 27, 'DATE'], [29, 39, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Saturday 11-08-07 at 5 pm local time, Mujahideen o..." with entities "[[9, 17, 'DATE'], [38, 48, 'NAME'], [105, 126, 'NA...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "With threat of eviction looming close, slum dwelle..." with entities "[[0, 9, 'CITY'], [13, 18, 'CITY'], [32, 70, 'INCID...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mumbai: A fire broke out in the Foreign Post Offic..." with entities "[[0, 6, 'CITY'], [8, 24, 'INCIDENT'], [32, 51, 'AR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Seven children and four others were killed and 13,..." with entities "[[0, 42, 'INCIDENT'], [96, 131, 'INCIDENT'], [135,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sunday 05-08-07, at 5 pm local time, Mujahideen of..." with entities "[[7, 15, 'DATE'], [37, 47, 'NAME'], [154, 160, 'DI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Just arrived in #Paris for a business trip with @A..." with entities "[[17, 22, 'CITY'], [29, 42, 'INCIDENT'], [49, 57, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Intelligence services of Islamic Emirate of Afghan..." with entities "[[79, 91, 'AREA'], [100, 106, 'STATE'], [335, 345,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "New Delhi:ï¿½A Pulwama-style terror strike was ave..." with entities "[[0, 9, 'CITY'], [13, 26, 'DISTRICT'], [27, 52, 'I...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Monday morning 13-08-07, Mujahideen of Islamic Emi..." with entities "[[0, 14, 'TIME'], [15, 23, 'DATE'], [25, 35, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Monday morning 13-08-07, Mujahideen of Islamic Emi..." with entities "[[0, 14, 'TIME'], [15, 24, 'DATE'], [25, 35, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "New Delhi: The Press Club of India (PCI) on Saturd..." with entities "[[0, 9, 'CITY'], [60, 94, 'INCIDENT'], [95, 108, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sunday morning 19-08-07, Mujahideen of Islamic Emi..." with entities "[[0, 14, 'TIME'], [15, 23, 'DATE'], [193, 211, 'DI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The accused, Samuel Andrew Pyster, had allegedly b..." with entities "[[13, 33, 'NAME'], [87, 103, 'NAME'], [264, 269, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thursday morning 16-08-07 at 10:30 am local time, ..." with entities "[[0, 16, 'TIME'], [17, 25, 'DATE'], [29, 48, 'TIME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sunday night 12-08-07, Mujahideen of Islamic Emira..." with entities "[[0, 12, 'TIME'], [13, 21, 'DATE'], [23, 33, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The 1970 Naxaliteâ€“Maoist insurgency in India was..." with entities "[[4, 8, 'DATE'], [39, 44, 'COUNTRY'], [52, 66, 'IN...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thursday 02-08-07, Mujahideen of Islamic Emirate O..." with entities "[[9, 17, 'DATE'], [19, 29, 'NAME'], [113, 121, 'NA...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Saturday 11-08-07, Islamic Emirate of Afghanistan ..." with entities "[[9, 17, 'DATE'], [60, 72, 'COUNTRY'], [108, 124, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Supreme Court on Monday said there cannot be a..." with entities "[[0, 17, 'ORGANISATION'], [33, 156, 'INCIDENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thursday night 02-08-07, Mujahideen of Islamic Emi..." with entities "[[0, 14, 'TIME'], [15, 23, 'DATE'], [25, 35, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Three suspected drug peddlers, arrested in the pro..." with entities "[[92, 112, 'NAME'], [171, 183, 'DATE'], [189, 195,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Friday 10-08-07 at 11 am local time, Mujahideen of..." with entities "[[7, 15, 'DATE'], [19, 35, 'TIME'], [37, 47, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tuesday morning 14-8-07 at 6 am local time, Mujahi..." with entities "[[0, 15, 'TIME'], [16, 23, 'DATE'], [27, 42, 'TIME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Epoch 0 -> 6091.613408949928
# Epoch 10 -> 3047.69962381572
# Epoch 20 -> 2551.033155390408

# %%
# Metrics
def evaluate(ner_model, examples):
    scorer = Scorer()
    example = []
    preds = []
    for input_, annotations in examples:
        pred = ner_model(input_)
        preds.append([(ent.text, ent.label_) for ent in pred.ents])
        temp = Example.from_dict(pred, annotations)
        example.append(temp)

    scores = scorer.score(example)
    return scores, preds

# %%
# Evaluation
result, preds = evaluate(nlp, test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The latest quarterly Gross Domestic Product data r..." with entities "[[963, 976, 'STATE'], [977, 981, 'CITY'], [986, 99...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "New Delhi:ï¿½The Delhi Police on Friday said it ha..." with entities "[[0, 9, 'CITY'], [15, 20, 'CITY'], [50, 150, 'INCI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thane: The toll in the Bhiwandi building collapse ..." with entities "[[0, 5, 'CITY'], [23, 31, 'CITY'], [32, 49, 'INCID...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Two Mujahideen of Islamic Emirate of Afghanistan M..." with entities "[[4, 14, 'NAME'], [49, 62, 'NAME'], [67, 83, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thursday morning 09-08-07, Mujahideen of Islamic E..." with entities "[[0, 16, 'TIME'], [17, 25, 'DATE'], [27, 37, 'NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(

# %%
def annotate(test):
  out = []
  for x in test:
    text = x[0]
    ents = x[1]
    res = []
    for e in ents['entities']:
      res.append((text[e[0] : e[1]], e[2]))
    out.append(res)
  return out

true_labels = annotate(test_data)

# %%
def performance(true, pred):
  tp, fn = 0, 0  # tp -> True Positive; fn -> False Negative
  fp, tn = 0, 0  # fp -> False Positive; tn -> True Negative

  assert len(true) == len(pred)

  m = len(true)

  for i in range(m):
    true_sample = true[i]
    pred_sample = pred[i]

    # True Positive
    for ent in true_sample:
      if ent in pred_sample:
        tp += 1
      else:
        fn += 1

    # True Negative
    for ent in pred_sample:
      if not ent in true_sample:
        fp += 1

  # Precision, Recall
  precision = tp / (tp + fp)
  recall = tp / (tp + fn)
  f1_score = (2 * precision * recall) / (precision + recall)

  print("Preformance:")
  print("Precision: ", precision)
  print("Recall: ", recall)
  print("F1 Score: ", f1_score)

  return f1_score, precision, recall

performance(true_labels, preds)
# Out:
# Preformance:
# Precision:  0.7432712215320911
# Recall:  0.6773584905660377
# F1 Score:  0.7087857847976308
# (0.7087857847976308, 0.7432712215320911, 0.6773584905660377)

# %%
# Save the model
output_dir = Path('/content/Trained Model')
if not output_dir.exists():
  output_dir.mkdir()
nlp.to_disk(output_dir)
print("Saved")

# Upload the folder into drive
# !zip -r '/content/Trained_Model.zip' '/content/Trained Model'
# !mv '/content/Trained_Model.zip' '/content/drive/MyDrive/'
print("Uploaded")
# Out:
# Saved
#   adding: content/Trained Model/ (stored 0%)
#   adding: content/Trained Model/attribute_ruler/ (stored 0%)
#   adding: content/Trained Model/attribute_ruler/patterns (deflated 84%)
#   adding: content/Trained Model/lemmatizer/ (stored 0%)
#   adding: content/Trained Model/lemmatizer/lookups/ (stored 0%)
#   adding: content/Trained Model/lemmatizer/lookups/lookups.bin (deflated 56%)
#   adding: content/Trained Model/tagger/ (stored 0%)
#   adding: content/Trained Model/tagger/model (deflated 8%)
#   adding: content/Trained Model/tagger/cfg (deflated 65%)
#   adding: content/Trained Model/config.cfg (deflated 73%)
#   adding: content/Trained Model/senter/ (stored 0%)
#   adding: content/Trained Model/senter/model (deflated 9%)
#   adding: content/Trained Model/senter/cfg (stored 0%)
#   adding: content/Trained Model/tok2vec/ (stored 0%)
#   adding: content/Trained Model/tok2vec/model (deflated 7%)
#   adding: content/Trained Model/tok2vec/cfg (stored 0%)
#   adding: content/Trained Model/vocab/ (stored 0%)
#   adding: content/Trained Model/vocab/vectors (deflated 10%)
#   adding: content/Trained Model/vocab/lookups.bin (deflated 43%)
#   adding: content/Trained Model/vocab/vectors.cfg (stored 0%)
#   adding: content/Trained Model/vocab/key2row (deflated 8%)
#   adding: content/Trained Model/vocab/strings.json (deflated 77%)
#   adding: content/Trained Model/tokenizer (deflated 81%)
#   adding: content/Trained Model/ner/ (stored 0%)
#   adding: content/Trained Model/ner/moves (deflated 79%)
#   adding: content/Trained Model/ner/model (deflated 7%)
#   adding: content/Trained Model/ner/cfg (deflated 33%)
#   adding: content/Trained Model/meta.json (deflated 69%)
#   adding: content/Trained Model/parser/ (stored 0%)
#   adding: content/Trained Model/parser/moves (deflated 55%)
#   adding: content/Trained Model/parser/model (deflated 7%)
#   adding: content/Trained Model/parser/cfg (deflated 32%)
# Uploaded

# %%
# Test on known
doc = nlp(test_data[-1][0])
print(test_data[-1][0])
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Saturday 25-08-07 at 4 pm local time, a Mujahid of Islamic Emirate of Afghanistan Mulwi Muhammad, carried out a martyrdom attack against a convoy of NATO Christian kafirs terrorists occupation militaries terrorists in on oli Charkhi highway in east of Kabul city. The martyrdom attack destroyed two vehicles, after ISAF Christian kafirs terrorists occupation militaries terrorists blocked the highway and transferred the terrorists died bodies by helicopter from area. Reported by Zabihuallah Mujahid
# Entities [('25-08-07', 'DATE'), ('4 pm', 'TIME'), ('Mujahid', 'NAME'), ('Islamic Emirate of Afghanistan', 'ORGANISATION'), ('Mulwi Muhammad', 'NAME'), ('NATO Christian kafirs', 'ORGANISATION'), ('oli Charkhi highway', 'AREA'), ('Kabul city.', 'CITY'), ('martyrdom attack destroyed two vehicles', 'INCIDENT'), ('ISAF Christian kafirs', 'ORGANISATION'), ('Zabihuallah Mujahid', 'NAME')]

# %%
# Create a output table
def create_table(model, data, name, save=True, hasLabels=True):
  """
  Gives out a csv file with Name, Date, Time, Area, City, District, State,
  Country as Column names
  """
  # Dictionary to store data
  table = {"NAME":[], "DATE":[], "TIME":[], "AREA":[], "CITY": [],
           "DISTRICT":[], "STATE":[], "COUNTRY":[], "ORGANISATION":[], "INCIDENT":[]}

  if hasLabels:
    for d in data:
      # Single sample
      row = {"NAME":[], "DATE":[], "TIME":[], "AREA":[], "CITY": [],
           "DISTRICT":[], "STATE":[], "COUNTRY":[], "ORGANISATION":[], "INCIDENT":[]}

      text = d
      pred = model(text)
      for ent in pred.ents:
        row[ent.label_].append(ent.text)

      # Append sample to table
      for k in table:
        table[k].append(row[k])
  else:
    for d in data:
      # Single sample
      row = {"NAME":[], "DATE":[], "TIME":[], "AREA":[], "CITY": [],
           "DISTRICT":[], "STATE":[], "COUNTRY":[], "ORGANISATION":[], "INCIDENT":[]}

      pred = model(d)
      for ent in pred.ents:
        row[ent.label_].append(ent.text)

      # Append sample to table
      for k in table:
        table[k].append(row[k])

  df = pd.DataFrame(table)

  # Save csv
  if save:
    df.to_csv(name)
  return df

#df = create_table(nlp, test_data, "Test_data_output.csv")
#df.sample(5)

# %%
# For the entire data
df = create_table(nlp, training_data["annotations"], "Outputs_Entire_Data.csv")
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-5e15c4750199> in <cell line: 2>()
#       1 # For the entire data
# ----> 2 df = create_table(nlp, training_data["annotations"], "Outputs_Entire_Data.csv")
#       3 df.sample(5)
#
# <ipython-input-18-2bee02cce84d> in create_table(model, data, name, save, hasLabels)
#      16
#      17       text = d
# ---> 18       pred = model(text)
#      19       for ent in pred.ents:
#      20         row[ent.label_].append(ent.text)
#
# /usr/local/lib/python3.10/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     997         DOCS: https://spacy.io/api/language#call
#     998         """
# --> 999         doc = self._ensure_doc(text)
#    1000         if component_cfg is None:
#    1001             component_cfg = {}
#
# /usr/local/lib/python3.10/dist-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1091         if isinstance(doc_like, bytes):
#    1092             return Doc(self.vocab).from_bytes(doc_like)
# -> 1093         raise ValueError(Errors.E1041.format(type=type(doc_like)))
#    1094
#    1095     def _ensure_doc_with_context(
#
# ValueError: [E1041] Expected a string, Doc, or bytes as input, but got: <class 'list'>

# %% [markdown]
# # Geocoding

# %%
# cleaning csv file
import pandas as pd

#df = pd.read_csv('/content/Outputs_Entire_Data.csv')

def destrip_table(df):
  #Removing "[]" from table
  df = df.apply(lambda x: x.astype(str).str.strip("[]"))
  return df

def deduplicate(cell):
  #Removing dulplicate values in each cell
  cell_list = cell.split(',')
  deduplicated_list = list(set(cell_list))
  return ','.join(deduplicated_list)

def clean_data(df):
  df = destrip_table(df)
  df = df.applymap(deduplicate)
  return df

##df.to_csv('deduplicated_data.csv', index=False)

# %%
import geopy
from geopy.geocoders import Nominatim
import requests
import csv

# %%
# Geocoding of CSV by concatenating different entities
def geocode(in_file):
  with open(in_file, 'r') as f_in:
    csv_reader = csv.reader(f_in)

    # we are using OpenStreetmaps Geocoder
    geolocator = Nominatim(user_agent="Garudaltics")

    # Removing heading
    header = next(csv_reader)
    with open('geocoded_data.csv', 'w', newline='') as f_out:
      csv_writer = csv.writer(f_out)

      # Adding lat, long headings
      header.append("latitude")
      header.append("longitude")
      csv_writer.writerow(header)

      # Concatenating Area, city, district, State, and Country
      for row in csv_reader:
        loc = row[4]
        loc = loc  + row[5]
        loc = loc  + row[6]
        loc = loc  + row[7]
        loc = loc + row[8]

        print(loc)

        # Geocoder on loc
        location = geolocator.geocode(loc, timeout=10000)
        # Removing low level entities one by one to get geocoding
        if location == None:
          loc1 = row[5]
          loc1 = loc1 + row[6]
          loc1 = loc1 + row[7]
          location = geolocator.geocode(loc1, timeout=10000)

          if location == None:
            loc2 = row[6]
            loc2 = loc2 + row[7]
            location = geolocator.geocode(loc2, timeout=10000)

            if location == None:
              loc3 = row[7]
              location = geolocator.geocode(loc3, timeout=10000)

              if location == None:
                print("Location not found")

              else:
                print((location.latitude, location.longitude))

                # Adding lat, long values to same column
                row.append(location.latitude)
                row.append(location.longitude)
                csv_writer.writerow(row)
            else:
              print((location.latitude, location.longitude))

              row.append(location.latitude)
              row.append(location.longitude)
              csv_writer.writerow(row)
          else:
            print((location.latitude, location.longitude))
            row.append(location.latitude)
            row.append(location.longitude)
            csv_writer.writerow(row)
        else:
          print((location.latitude, location.longitude))
          row.append(location.latitude)
          row.append(location.longitude)
          csv_writer.writerow(row)
  print("Done.")

# %% [markdown]
# # Map visualization

# %%
# !pip install --upgrade plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.8/dist-packages (5.5.0)
# Collecting plotly
#   Downloading plotly-5.13.0-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 44.1 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly) (8.2.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# Successfully installed plotly-5.13.0

# %%
# load csv into dataframe
import pandas as pd
import plotly.express as px

# df_map = pd.read_csv('/content/geocoded_test_data_1.csv')

# %%
def plot_on_map(df_map):
  fig = px.scatter_mapbox(df_map, lat="latitude", lon="longitude",
                        color_continuous_scale=px.colors.cyclical.IceFire,
                        size_max=15, zoom=5, mapbox_style="open-street-map",
                        hover_name="NAME", hover_data=["DATE", "TIME"])
  fig.update_traces(marker=dict(size=10, color="black"))
  fig.show()

# %% [markdown]
# #Export to shapefile

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from geopandas) (21.3)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.8/dist-packages (from geopandas) (2.0.0)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 42.0 MB/s eta 0:00:00
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 81.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (22.2.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->geopandas) (3.0.9)
# Installing collected packages: pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.1

# %%
import geopandas as gpd

def export(infile):
  df = pd.read_csv("geocoded_data.csv")

  # convert the DataFrame to a GeoDataFrame
  gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
  gdf.crs = "EPSG:4326"
  gdf.to_file("point_data.shp", driver="ESRI Shapefile")

#gdf.to_file("point_data.geojson", driver="GeoJSON")
# Out:
# ---------------------------------------------------------------------------
# DriverError                               Traceback (most recent call last)
# <ipython-input-29-4cfe9640dc64> in <module>
#      15 #gdf.to_file("point_data.geojson", driver="GeoJSON")
#      16
# ---> 17 gdf.to_file("point_data.kml", driver="Kml")
#
# /usr/local/lib/python3.8/dist-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#    1201         from geopandas.io.file import _to_file
#    1202
# -> 1203         _to_file(self, filename, driver, schema, index, **kwargs)
#    1204
#    1205     def set_crs(self, crs=None, epsg=None, inplace=False, allow_override=False):
#
# /usr/local/lib/python3.8/dist-packages/geopandas/io/file.py in _to_file(df, filename, driver, schema, index, mode, crs, engine, **kwargs)
#     543
#     544     if engine == "fiona":
# --> 545         _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     546     elif engine == "pyogrio":
#     547         _to_file_pyogrio(df, filename, driver, schema, crs, mode, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/geopandas/io/file.py in _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     570         elif crs:
#     571             crs_wkt = crs.to_wkt("WKT1_GDAL")
# --> 572         with fiona.open(
#     573             filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     574         ) as colxn:
#
# /usr/local/lib/python3.8/dist-packages/fiona/env.py in wrapper(*args, **kwargs)
#     406     def wrapper(*args, **kwargs):
#     407         if local._env:
# --> 408             return f(*args, **kwargs)
#     409         else:
#     410             if isinstance(args[0], str):
#
# /usr/local/lib/python3.8/dist-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     278             else:
#     279                 this_schema = None
# --> 280             c = Collection(path, mode, crs=crs, driver=driver, schema=this_schema,
#     281                            encoding=encoding, layer=layer, enabled_drivers=enabled_drivers, crs_wkt=crs_wkt,
#     282                            **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     134                 raise DriverError("no driver")
#     135             elif driver not in supported_drivers:
# --> 136                 raise DriverError(
#     137                     "unsupported driver: %r" % driver)
#     138             elif self.mode not in supported_drivers[driver]:
#
# DriverError: unsupported driver: 'Kml'

# %% [markdown]
# ## Inference - Sample Procedure

# %%
# Load the data
with open("/content/report_96_5_05-11-07.txt", "r") as infile:
  data = infile.read()
  data = data.split("\n")
print(data)
# Out:
# ['Sunday night 4-11-07 at 9 pm local time, Mujahideen of Islamic Emirate of Afghanistan ambushed an enemy convoy in Pashi Band area of Sewri district of Zabul province. In the attack a firefight started which lasted for half an hour, in which three tanks were destroyed and more than 12 Christian terrorists were killed and a number of them were wounded. Later occupation military blocked the road between district Qallat capital city of province and bombarded the area but their were no causalities on Mujahideen side. Reported by Qari Muhammad Yousuf', 'Sunday morning 4-11-07 at 10 am local time, NATO terrorists attacked a Mujahideen post in Khol abad and Chini area of Kajaki district of Helmand province. In the attack firefight started in which Mujahideen killed 10 terrorists and enemy attack was defeated.', 'Mujahideen of Islamic Emirate of Afghanistan have blocked Kandahar and Uruzgan highway from the use of enemy in Buragamn area of Shah Walikot district of Kandahar province. Saturday puppet army tried to use the highway but were unsuccessful, as Mujahideen attack them a small firefight started in which Mujahideen killed 3 terrorists attack them defeated and three soldiers were killed.', 'Saturday night 3-11-07, Mujahideen of Islamic Emirate of Afghanistan fired Mortar shells on Meadan Shar airport where a large number of American terrorists live. A huge fire was seen after fired mortars struck park vehicles, 2 vehicles were destroyed. Also Saturday night 3-11-07 at 11.50 pm local time, Mujahideen fired 4 Mortar shells on Fareab airport where a large number of NATO kafir and Afghan munafiq terrorists live. Fired mortar struck the base but the damages and casualties to the enemies of Islam could not be confirmed in there entireties.', 'Saturday afternoon 3-11-07 Mujahideen of Islamic Emirate of Afghanistan defeated an attacked of NATO and their Afghan puppets in Khaton area of Ghormach district of Badghis province. According to the report a number of enemies were killed and few were wounded, in this 3 hour firefight a Mujahid was martyred and three were wounded, later the enemy arrested civilians.', 'Monday morning 5-11-07 at 10 am local time, Mujahideen of Islamic Emirate of Afghanistan attacked puppets in Torghak, Boragan and Kata Sang area of Shahwalikot district of Kandahar province, when they were trying to open the Uruzgan and Kandahar highway, which has been blocked by Mujahideen from last five days. In the attacks firefighting started which lasted for six hours, in which more than 25 puppet terrorists were killed and many were wounded. Later enemy military bombarded the area but their were no causalities on Mujahideen side.', 'Tuesday morning 6-11-07 at 10 am local time, Mujahideen of Islamic Emirate of Afghanistan ambushed enemy convoy which was supported by on foot puppet army terrorists in Ashigho area of Zhari district of Kandahar province. In the attack a firefight started which lasted for half an hour, in which 4 tanks were destroyed and more than 8 Christian terrorists were and a number of puppet foot patrolling terrorists were also killed and wounded. Later enemy military blocked the Herat and Kandahar highway. Reported by Qari Muhammad Yousuf', 'Tuesday morning 6-11-07 at 10 am local time, Mujahideen of Islamic Emirate of Afghanistan with remote controlled landmines blew up a truck of puppet police in Baladeh area of Gardize capital city of Paktia province. The landmine destroyed the truck and 10 enemies of Islam terrorists in the truck were killed and 5 were wounded.', 'Monday afternoon 5-11-07, Mujahideen of Islamic Emirate of Afghanistan were attacked by NATO and their Afghan puppets in Khaton and Torjan area of Ghormach district of Badghis province. According to the reports firefighting and enemy bombardment continued in the area but the casualties of enemy were not reported, there were no casualties to the Mujahideen side. Also Monday night 5-11-07, Mujahideen attacked with a light and heavy weapons on pup ...

# %%
# Load the model
nlp = spacy.load('/content/Trained_Model/content/Trained Model')

# %%
ner = nlp.get_pipe("ner")
labels = ner.labels
print(labels)
# Out:
# ('AREA', 'CARDINAL', 'CITY', 'COUNTRY', 'DATE', 'DISTRICT', 'EVENT', 'FAC', 'GPE', 'INCIDENT', 'LANGUAGE', 'LAW', 'LOC', 'LOCATION', 'MONEY', 'NAME', 'NORP', 'ORDINAL', 'ORG', 'ORGANISATION', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'STATE', 'TIME', 'WORK_OF_ART')

# %%
# Get output table
df = create_table(nlp, data, "Outputs.csv", save=False)
df.head(3)
# Out:
#                                                 NAME       DATE  \
# 0  [Mujahideen, Christian, Mujahideen, Qari Muham...  [4-11-07]
# 1                           [Mujahideen, Mujahideen]  [4-11-07]
# 2               [Mujahideen, Mujahideen, Mujahideen]         []
#
#                        TIME                                           AREA  \
# 0  [Sunday night, 9 pm, 12]                              [Pashi Band area]
# 1   [Sunday morning, 10 am]                                   [Chini area]
# 2                        []  [Kandahar and Uruzgan highway, Buragamn area]
#
#                     CITY                      DISTRICT                 STATE  \
# 0  [Qallat capital city]                       [Sewri]               [Zabul]
# 1                     []  [Khol abad, Kajaki district]   [Helmand province.]
# 2                     []       [Shah Walikot district]  [Kandahar province.]
#
#   COUNTRY                      ORGANISATION  \
# 0      []  [Islamic Emirate of Afghanistan]
# 1      []                 [NATO terrorists]
# 2      []  [Islamic Emirate of Afghanistan]
#
#                                             INCIDENT
# 0  [ambushed an enemy convoy, three tanks were de...
# 1                                                 []
# 2                                                 []

# %%
# Clean the table
df = clean_data(df)
df.head(3)

# Save the output
df.to_csv("Outputs.csv")

# %%
# Geocode
geocode("Outputs.csv")
# Out:
# 'Pashi Band area''Qallat capital city''Sewri''Zabul'
# (32.3068942, 67.129904)
# 'Chini area''Khol abad', 'Kajaki district''Helmand province.'
# (31.0, 64.0)
#  'Buragamn area','Kandahar and Uruzgan highway''Shah Walikot district''Kandahar province.'
# (30.9910033, 65.7068525)
#  'Fareab','Meadan Shar airport'
# Location not found
# 'Khaton area''Ghormach''Badghis province.'
# (35.720631, 63.779506)
# 'Boragan and Kata Sang''Kandahar''Shahwalikot district''Kandahar province'
# (30.9910033, 65.7068525)
#  'Herat and','Ashigho area''Kandahar''Zhari''Kandahar'
# (31.6161203, 65.5755008)
# 'Baladeh area''Gardize capital city''Paktia province.'
# (33.705724, 69.4083555)
#  'Ghol azbak area','Torjan area''Khaton''Ghormach', 'Sang Atash' 'Badghis province.','Badghis province.'
# (34.7582024, 63.0203661)
#
# Location not found
# Done.

# %%
# Visualize
df_map = pd.read_csv("geocoded_data.csv")
plot_on_map(df_map)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.0.min.js"></script>                <div id="23e064f0-ee19-4dd2-b4ae-56c925fca2ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23e064f0-ee19-4dd2-b4ae-56c925fca2ec")) {                    Plotly.newPlot(                        "23e064f0-ee19-4dd2-b4ae-56c925fca2ec",                        [{"customdata":[["'4-11-07'"," '12','Sunday night', '9 pm'"],["'4-11-07'","'Sunday morning', '10 am'"],[null,null],["'3-11-07'","'Saturday afternoon'"],["'5-11-07'"," '25 puppet','Monday morning', '10 am'"],["'6-11-07'","'Tuesday morning', '10 am'"],["'6-11-07'","'Tuesday morning', '10 am'"],["'5-11-07', '5-11-07'"," 'Monday night','Monday afternoon'"]],"hovertemplate":"<b>%{hovertext}</b><br><br>latitude=%{lat}<br>longitude=%{lon}<br>DATE=%{customdata[0]}<br>TIME=%{customdata[1]}<extra></extra>","hovertext":[" 'Christian','Mujahideen', 'Qari Muhammad Yousuf', 'Mujahideen'","'Mujahideen', 'Mujahideen'","'Mujahideen', 'Mujahideen'","'Mujahideen', 'Mujahid', 'NATO', 'Afghan puppets'","'Mujahideen', 'Mujahideen'"," 'Christian','Mujahideen', 'Qari Muhammad Yousuf'","'Mujahideen'","'Mujahideen', 'NATO', 'Qari Muhammad Yousuf', 'Afghan puppets', 'Mujahideen'"],"lat":[32.3068942,31.0,30.9910033,35.720631,30.9910033,31.6161203,33.705724,34.7582024],"legendgroup":"","lon":[67.129904,64.0,65.7068525,63.779506,65.7068525,65.5755008,69.4083555,63.0203661],"marker":{"color":"black","size":10},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e ...
